# %%
def image_file_generator(images_dir, metadata_df):
    """
    Generator function that yields image paths if the image is present
    in the metadata DataFrame.

    :param images_dir: Directory containing images
    :param metadata_df: DataFrame containing metadata with 'Image Index' column
    :yield: Full path to the image file
    """
    for image_name in metadata_df['Image Index']:
        image_path = os.path.join(images_dir, image_name)
        if os.path.isfile(image_path):
            yield image_path

# %%
# Use the generator to create a list of training and test image files
train_image_files = list(image_file_generator(images_dir, train_metadata))
test_image_files = list(image_file_generator(images_dir, test_metadata))

# %%
import os
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed

def organize_images(metadata_df, source_dir, target_dir):
    # Create a dictionary for faster lookups
    label_dict = {os.path.basename(row['Image Index']): 'Pneumothorax' if 'Pneumothorax' in row['Finding Labels'] else 'No_Finding'
                  for index, row in metadata_df.iterrows()}

    # Define a function for copying a single file
    def copy_file(image_path):
        label = label_dict[os.path.basename(image_path)]
        label_dir = label
        dest_path = os.path.join(target_dir, label_dir, os.path.basename(image_path))
        shutil.copy(image_path, dest_path)
        return image_path

    # Use ThreadPoolExecutor for multithreading
    with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
        # Submit all copy tasks and get a list of futures
        futures = [executor.submit(copy_file, image_path) for image_path in image_file_generator(source_dir, metadata_df)]
        
        # Progress indicator
        total_files = len(futures)
        processed_files = 0
        for future in as_completed(futures):
            processed_files += 1
            if processed_files % 100 == 0:  # Update every 100 files, adjust this number as needed
                print(f"Processed {processed_files}/{total_files} files.")

# Organize training images
organize_images(train_metadata, images_dir, os.path.join(dataset_folder_path, 'data/train'))

# Organize validation images
organize_images(test_metadata, images_dir, os.path.join(dataset_folder_path, 'data/val'))
# Out:
# Processed 100/48791 files.
# Processed 200/48791 files.
# Processed 300/48791 files.
# Processed 400/48791 files.
# Processed 500/48791 files.
# Processed 600/48791 files.
# Processed 700/48791 files.
# Processed 800/48791 files.
# Processed 900/48791 files.
# Processed 1000/48791 files.
# Processed 1100/48791 files.
# Processed 1200/48791 files.
# Processed 1300/48791 files.
# Processed 1400/48791 files.
# Processed 1500/48791 files.
# Processed 1600/48791 files.
# Processed 1700/48791 files.
# Processed 1800/48791 files.
# Processed 1900/48791 files.
# Processed 2000/48791 files.
# Processed 2100/48791 files.
# Processed 2200/48791 files.
# Processed 2300/48791 files.
# Processed 2400/48791 files.
# Processed 2500/48791 files.
# Processed 2600/48791 files.
# Processed 2700/48791 files.
# Processed 2800/48791 files.
# Processed 2900/48791 files.
# Processed 3000/48791 files.
# Processed 3100/48791 files.
# Processed 3200/48791 files.
# Processed 3300/48791 files.
# Processed 3400/48791 files.
# Processed 3500/48791 files.
# Processed 3600/48791 files.
# Processed 3700/48791 files.
# Processed 3800/48791 files.
# Processed 3900/48791 files.
# Processed 4000/48791 files.
# Processed 4100/48791 files.
# Processed 4200/48791 files.
# Processed 4300/48791 files.
# Processed 4400/48791 files.
# Processed 4500/48791 files.
# Processed 4600/48791 files.
# Processed 4700/48791 files.
# Processed 4800/48791 files.
# Processed 4900/48791 files.
# Processed 5000/48791 files.
# Processed 5100/48791 files.
# Processed 5200/48791 files.
# Processed 5300/48791 files.
# Processed 5400/48791 files.
# Processed 5500/48791 files.
# Processed 5600/48791 files.
# Processed 5700/48791 files.
# Processed 5800/48791 files.
# Processed 5900/48791 files.
# Processed 6000/48791 files.
# Processed 6100/48791 files.
# Processed 6200/48791 files.
# Processed 6300/48791 files.
# Processed 6400/48791 files.
# Processed 6500/48791 files.
# Processed 6600/48791 files.
# Processed 6700/48791 files.
# Processed 6800/48791 files.
# Processed 6900/48791 files.
# Processed 7000/48791 files.
# Processed 7100/48791 files.
# Processed 7200/48791 files.
# Processed 7300/48791 files.
# Processed 7400/48791 files.
# Processed 7500/48791 files.
# Processed 7600/48791 files.
# Processed 7700/48791 files.
# Processed 7800/48791 files.
# Processed 7900/48791 files.
# Processed 8000/48791 files.
# Processed 8100/48791 files.
# Processed 8200/48791 files.
# Processed 8300/48791 files.
# Processed 8400/48791 files.
# Processed 8500/48791 files.
# Processed 8600/48791 files.
# Processed 8700/48791 files.
# Processed 8800/48791 files.
# Processed 8900/48791 files.
# Processed 9000/48791 files.
# Processed 9100/48791 files.
# Processed 9200/48791 files.
# Processed 9300/48791 files.
# Processed 9400/48791 files.
# Processed 9500/48791 files.
# Processed 9600/48791 files.
# Processed 9700/48791 files.
# Processed 9800/48791 files.
# Processed 9900/48791 files.
# Processed 10000/48791 files.
# Processed 10100/48791 files.
# Processed 10200/48791 files.
# Processed 10300/48791 files.
# Processed 10400/48791 files.
# Processed 10500/48791 files.
# Processed 10600/48791 files.
# Processed 10700/48791 files.
# Processed 10800/48791 files.
# Processed 10900/48791 files.
# Processed 11000/48791 files.
# Processed 11100/48791 files.
# Processed 11200/48791 files.
# Processed 11300/48791 files.
# Processed 11400/48791 files.
# Processed 11500/48791 files.
# Processed 11600/48791 files.
# Processed 11700/48791 files.
# Processed 11800/48791 files.
# Processed 11900/48791 files.
# Processed 12000/48791 files.
# Processed 12100/48791 files.
# Processed 12200/48791 files.
# Processed 12300/48791 files.
# Processed 12400/48791 files.
# Processed 12500/48791 files.
# Processed 12600/48791 files.
# Processed 12700/48791 files.
# Processed 12800/48791 files.
# Processed 12900/48791 files.
# Processed 13000/48791 files.
# Processed 13100/48791 files.
# Processed 13200/48791 files.
# Processed 13300/48791 files.
# Processed 13400/48791 files.
# Processed 13500/48791 files.
# Processed 13600/48791 files.
# Processed 13700/48791 files.
# Processed 13800/48791 files.
# Processed 13900/48791 files.
# Processed 14000/48791 files.
# Processed 14100/48791 files.
# Processed 14200/48791 files.
# Processed 14300/48791 files.
# Processed 14400/48791 files.
# Processed 14500/48791 files.
# Processed 14600/48791 files.
# Processed 14700/48791 files.
# Processed 14800/48791 files.
# Processed 14900/48791 files.
# Processed 15000/48791 files.
# Processed 15100/48791 files.
# Processed 15200/48791 files.
# Processed 15300/48791 files.
# Processed 15400/48791 files.
# Processed 15500/48791 files.
# Processed 15600/48791 files.
# Processed 15700/48791 files.
# Processed 15800/48791 files.
# Processed 15900/48791 files.
# Processed 16000/48791 files.
# Processed 16100/48791 files.
# Processed 16200/48791 files.
# Processed 16300/48791 files.
# Processed 16400/48791 files.
# Processed 16500/48791 files.
# Processed 16600/48791 files.
# Processed 16700/48791 files.
# Processed 16800/48791 files.
# Processed 16900/48791 files.
# Processed 17000/48791 files.
# Processed 17100/48791 files.
# Processed 17200/48791 files.
# Processed 17300/48791 files.
# Processed 17400/48791 files.
# Processed 17500/48791 files.
# Processed 17600/48791 files.
# Processed 17700/48791 files.
# Processed 17800/48791 files.
# Processed 17900/48791 files.
# Processed 18000/48791 files.
# Processed 18100/48791 files.
# Processed 18200/48791 files.
# Processed 18300/48791 files.
# Processed 18400/48791 files.
# Processed 18500/48791 files.
# Processed 18600/48791 files.
# Processed 18700/48791 files.
# Processed 18800/48791 files.
# Processed 18900/48791 files.
# Processed 19000/48791 files.
# Processed 19100/48791 files.
# Processed 19200/48791 files.
# Processed 19300/48791 files.
# Processed 19400/48791 files.
# Processed 19500/48791 files.
# Processed 19600/48791 files.
# Processed 19700/48791 files.
# Processed 19800/48791 files.
# Processed 19900/48791 files.
# Processed 20000/48791 files.
# Processed 20100/48791 files.
# Processed 20200/48791 files.
# Processed 20300/48791 files.
# Processed 20400/48791 files.
# Processed 20500/48791 files.
# Processed 20600/48791 files.
# Processed 20700/48791 files.
# Processed 20800/48791 files.
# Processed 20900/48791 files.
# Processed 21000/48791 files.
# Processed 21100/48791 files.
# Processed 21200/48791 files.
# Processed 21300/48791 files.
# Processed 21400/48791 files.
# Processed 21500/48791 files.
# Processed 21600/48791 files.
# Processed 21700/48791 files.
# Processed 21800/48791 files.
# Processed 21900/48791 files.
# Processed 22000/48791 files.
# Processed 22100/48791 files.
# Processed 22200/48791 files.
# Processed 22300/48791 files.
# Processed 22400/48791 files.
# Processed 22500/48791 files.
# Processed 22600/48791 files.
# Processed 22700/48791 files.
# Processed 22800/48791 files.
# Processed 22900/48791 files.
# Processed 23000/48791 files.
# Processed 23100/48791 files.
# Processed 23200/48791 files.
# Processed 23300/48791 files.
# Processed 23400/48791 files.
# Processed 23500/48791 files.
# Processed 23600/48791 files.
# Processed 23700/48791 files.
# Processed 23800/48791 files.
# Processed 23900/48791 files.
# Processed 24000/48791 files.
# Processed 24100/48791 files.
# Processed 24200/48791 files.
# Processed 24300/48791 files.
# Processed 24400/48791 files.
# Processed 24500/48791 files.
# Processed 24600/48791 files.
# Processed 24700/48791 files.
# Processed 24800/48791 files.
# Processed 24900/48791 files.
# Processed 25000/48791 files.
# Processed 25100/48791 files.
# Processed 25200/48791 files.
# Processed 25300/48791 files.
# Processed 25400/48791 files.
# Processed 25500/48791 files.
# Processed 25600/48791 files.
# Processed 25700/48791 files.
# Processed 25800/48791 files.
# Processed 25900/48791 files.
# Processed 26000/48791 files.
# Processed 26100/48791 files.
# Processed 26200/48791 files.
# Processed 26300/48791 files.
# Processed 26400/48791 files.
# Processed 26500/48791 files.
# Processed 26600/48791 files.
# Processed 26700/48791 files.
# Processed 26800/48791 files.
# Processed 26900/48791 files.
# Processed 27000/48791 files.
# Processed 27100/48791 files.
# Processed 27200/48791 files.
# Processed 27300/48791 files.
# Processed 27400/48791 files.
# Processed 27500/48791 files.
# Processed 27600/48791 files.
# Processed 27700/48791 files.
# Processed 27800/48791 files.
# Processed 27900/48791 files.
# Processed 28000/48791 files.
# Processed 28100/48791 files.
# Processed 28200/48791 files.
# Processed 28300/48791 files.
# Processed 28400/48791 files.
# Processed 28500/48791 files.
# Processed 28600/48791 files.
# Processed 28700/48791 files.
# Processed 28800/48791 files.
# Processed 28900/48791 files.
# Processed 29000/48791 files.
# Processed 29100/48791 files.
# Processed 29200/48791 files.
# Processed 29300/48791 files.
# Processed 29400/48791 files.
# Processed 29500/48791 files.
# Processed 29600/48791 files.
# Processed 29700/48791 files.
# Processed 29800/48791 files.
# Processed 29900/48791 files.
# Processed 30000/48791 files.
# Processed 30100/48791 files.
# Processed 30200/48791 files.
# Processed 30300/48791 files.
# Processed 30400/48791 files.
# Processed 30500/48791 files.
# Processed 30600/48791 files.
# Processed 30700/48791 files.
# Processed 30800/48791 files.
# Processed 30900/48791 files.
# Processed 31000/48791 files.
# Processed 31100/48791 files.
# Processed 31200/48791 files.
# Processed 31300/48791 files.
# Processed 31400/48791 files.
# Processed 31500/48791 files.
# Processed 31600/48791 files.
# Processed 31700/48791 files.
# Processed 31800/48791 files.
# Processed 31900/48791 files.
# Processed 32000/48791 files.
# Processed 32100/48791 files.
# Processed 32200/48791 files.
# Processed 32300/48791 files.
# Processed 32400/48791 files.
# Processed 32500/48791 files.
# Processed 32600/48791 files.
# Processed 32700/48791 files.
# Processed 32800/48791 files.
# Processed 32900/48791 files.
# Processed 33000/48791 files.
# Processed 33100/48791 files.
# Processed 33200/48791 files.
# Processed 33300/48791 files.
# Processed 33400/48791 files.
# Processed 33500/48791 files.
# Processed 33600/48791 files.
# Processed 33700/48791 files.
# Processed 33800/48791 files.
# Processed 33900/48791 files.
# Processed 34000/48791 files.
# Processed 34100/48791 files.
# Processed 34200/48791 files.
# Processed 34300/48791 files.
# Processed 34400/48791 files.
# Processed 34500/48791 files.
# Processed 34600/48791 files.
# Processed 34700/48791 files.
# Processed 34800/48791 files.
# Processed 34900/48791 files.
# Processed 35000/48791 files.
# Processed 35100/48791 files.
# Processed 35200/48791 files.
# Processed 35300/48791 files.
# Processed 35400/48791 files.
# Processed 35500/48791 files.
# Processed 35600/48791 files.
# Processed 35700/48791 files.
# Processed 35800/48791 files.
# Processed 35900/48791 files.
# Processed 36000/48791 files.
# Processed 36100/48791 files.
# Processed 36200/48791 files.
# Processed 36300/48791 files.
# Processed 36400/48791 files.
# Processed 36500/48791 files.
# Processed 36600/48791 files.
# Processed 36700/48791 files.
# Processed 36800/48791 files.
# Processed 36900/48791 files.
# Processed 37000/48791 files.
# Processed 37100/48791 files.
# Processed 37200/48791 files.
# Processed 37300/48791 files.
# Processed 37400/48791 files.
# Processed 37500/48791 files.
# Processed 37600/48791 files.
# Processed 37700/48791 files.
# Processed 37800/48791 files.
# Processed 37900/48791 files.
# Processed 38000/48791 files.
# Processed 38100/48791 files.
# Processed 38200/48791 files.
# Processed 38300/48791 files.
# Processed 38400/48791 files.
# Processed 38500/48791 files.
# Processed 38600/48791 files.
# Processed 38700/48791 files.
# Processed 38800/48791 files.
# Processed 38900/48791 files.
# Processed 39000/48791 files.
# Processed 39100/48791 files.
# Processed 39200/48791 files.
# Processed 39300/48791 files.
# Processed 39400/48791 files.
# Processed 39500/48791 files.
# Processed 39600/48791 files.
# Processed 39700/48791 files.
# Processed 39800/48791 files.
# Processed 39900/48791 files.
# Processed 40000/48791 files.
# Processed 40100/48791 files.
# Processed 40200/48791 files.
# Processed 40300/48791 files.
# Processed 40400/48791 files.
# Processed 40500/48791 files.
# Processed 40600/48791 files.
# Processed 40700/48791 files.
# Processed 40800/48791 files.
# Processed 40900/48791 files.
# Processed 41000/48791 files.
# Processed 41100/48791 files.
# Processed 41200/48791 files.
# Processed 41300/48791 files.
# Processed 41400/48791 files.
# Processed 41500/48791 files.
# Processed 41600/48791 files.
# Processed 41700/48791 files.
# Processed 41800/48791 files.
# Processed 41900/48791 files.
# Processed 42000/48791 files.
# Processed 42100/48791 files.
# Processed 42200/48791 files.
# Processed 42300/48791 files.
# Processed 42400/48791 files.
# Processed 42500/48791 files.
# Processed 42600/48791 files.
# Processed 42700/48791 files.
# Processed 42800/48791 files.
# Processed 42900/48791 files.
# Processed 43000/48791 files.
# Processed 43100/48791 files.
# Processed 43200/48791 files.
# Processed 43300/48791 files.
# Processed 43400/48791 files.
# Processed 43500/48791 files.
# Processed 43600/48791 files.
# Processed 43700/48791 files.
# Processed 43800/48791 files.
# Processed 43900/48791 files.
# Processed 44000/48791 files.
# Processed 44100/48791 files.
# Processed 44200/48791 files.
# Processed 44300/48791 files.
# Processed 44400/48791 files.
# Processed 44500/48791 files.
# Processed 44600/48791 files.
# Processed 44700/48791 files.
# Processed 44800/48791 files.
# Processed 44900/48791 files.
# Processed 45000/48791 files.
# Processed 45100/48791 files.
# Processed 45200/48791 files.
# Processed 45300/48791 files.
# Processed 45400/48791 files.
# Processed 45500/48791 files.
# Processed 45600/48791 files.
# Processed 45700/48791 files.
# Processed 45800/48791 files.
# Processed 45900/48791 files.
# Processed 46000/48791 files.
# Processed 46100/48791 files.
# Processed 46200/48791 files.
# Processed 46300/48791 files.
# Processed 46400/48791 files.
# Processed 46500/48791 files.
# Processed 46600/48791 files.
# Processed 46700/48791 files.
# Processed 46800/48791 files.
# Processed 46900/48791 files.
# Processed 47000/48791 files.
# Processed 47100/48791 files.
# Processed 47200/48791 files.
# Processed 47300/48791 files.
# Processed 47400/48791 files.
# Processed 47500/48791 files.
# Processed 47600/48791 files.
# Processed 47700/48791 files.
# Processed 47800/48791 files.
# Processed 47900/48791 files.
# Processed 48000/48791 files.
# Processed 48100/48791 files.
# Processed 48200/48791 files.
# Processed 48300/48791 files.
# Processed 48400/48791 files.
# Processed 48500/48791 files.
# Processed 48600/48791 files.
# Processed 48700/48791 files.
# Processed 100/8734 files.
# Processed 200/8734 files.
# Processed 300/8734 files.
# Processed 400/8734 files.
# Processed 500/8734 files.
# Processed 600/8734 files.
# Processed 700/8734 files.
# Processed 800/8734 files.
# Processed 900/8734 files.
# Processed 1000/8734 files.
# Processed 1100/8734 files.
# Processed 1200/8734 files.
# Processed 1300/8734 files.
# Processed 1400/8734 files.
# Processed 1500/8734 files.
# Processed 1600/8734 files.
# Processed 1700/8734 files.
# Processed 1800/8734 files.
# Processed 1900/8734 files.
# Processed 2000/8734 files.
# Processed 2100/8734 files.
# Processed 2200/8734 files.
# Processed 2300/8734 files.
# Processed 2400/8734 files.
# Processed 2500/8734 files.
# Processed 2600/8734 files.
# Processed 2700/8734 files.
# Processed 2800/8734 files.
# Processed 2900/8734 files.
# Processed 3000/8734 files.
# Processed 3100/8734 files.
# Processed 3200/8734 files.
# Processed 3300/8734 files.
# Processed 3400/8734 files.
# Processed 3500/8734 files.
# Processed 3600/8734 files.
# Processed 3700/8734 files.
# Processed 3800/8734 files.
# Processed 3900/8734 files.
# Processed 4000/8734 files.
# Processed 4100/8734 files.
# Processed 4200/8734 files.
# Processed 4300/8734 files.
# Processed 4400/8734 files.
# Processed 4500/8734 files.
# Processed 4600/8734 files.
# Processed 4700/8734 files.
# Processed 4800/8734 files.
# Processed 4900/8734 files.
# Processed 5000/8734 files.
# Processed 5100/8734 files.
# Processed 5200/8734 files.
# Processed 5300/8734 files.
# Processed 5400/8734 files.
# Processed 5500/8734 files.
# Processed 5600/8734 files.
# Processed 5700/8734 files.
# Processed 5800/8734 files.
# Processed 5900/8734 files.
# Processed 6000/8734 files.
# Processed 6100/8734 files.
# Processed 6200/8734 files.
# Processed 6300/8734 files.
# Processed 6400/8734 files.
# Processed 6500/8734 files.
# Processed 6600/8734 files.
# Processed 6700/8734 files.
# Processed 6800/8734 files.
# Processed 6900/8734 files.
# Processed 7000/8734 files.
# Processed 7100/8734 files.
# Processed 7200/8734 files.
# Processed 7300/8734 files.
# Processed 7400/8734 files.
# Processed 7500/8734 files.
# Processed 7600/8734 files.
# Processed 7700/8734 files.
# Processed 7800/8734 files.
# Processed 7900/8734 files.
# Processed 8000/8734 files.
# Processed 8100/8734 files.
# Processed 8200/8734 files.
# Processed 8300/8734 files.
# Processed 8400/8734 files.
# Processed 8500/8734 files.
# Processed 8600/8734 files.
# Processed 8700/8734 files.
